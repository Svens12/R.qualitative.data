# %%
shirts<-c('S','M','L','XL','XXL','M','L','XL','XXL','S','M')
shirts
# Out:
#  [1] "S"   "M"   "L"   "XL"  "XXL" "M"   "L"   "XL"  "XXL" "S"   "M"

# %%
shirts_sizes<-factor(shirts)
shirts_sizes
# Out:
#  [1] S   M   L   XL  XXL M   L   XL  XXL S   M
# Levels: L M S XL XXL

# %%
str(shirts_sizes)
# Out:
#  Factor w/ 5 levels "L","M","S","XL",..: 3 2 1 4 5 2 1 4 5 3 ...

# %%
summary(shirts_sizes)
# Out:
#   L   M   S  XL XXL
#   2   3   2   2   2

# %%
levels(shirts_sizes)
# Out:
# [1] "L"   "M"   "S"   "XL"  "XXL"

# %%
levels(shirts)
# Out:
# NULL

# %%
table(shirts_sizes)
# Out:
# shirts_sizes
#   L   M   S  XL XXL
#   2   3   2   2   2
